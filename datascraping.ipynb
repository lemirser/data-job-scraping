# %% [markdown]
# # Data scraping

# %% [markdown]
# ## Objectives
# Scrape data from Indeed website
#
# ## Resources
# Scraping tutorial: https://www.youtube.com/watch?v=8dTpNajxaH0&ab_channel=AlexTheAnalyst
#
# Data source: https://ph.indeed.com/

# %%
# Import necessary packages
from bs4 import BeautifulSoup
import requests

# %%
# url = "https://www.glassdoor.com/blog/tag/job-search/"
url = url = "https://www.jobstreet.com.ph/data-analyst-jobs"

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html') # Pull the information from the URL

# %%
print(soup)

#print(soup.find_all(id="FindJobs"))
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="Jobstreet" name="apple-mobile-web-app-title"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="MC41MzA5Njk5MzI0MTM5NDc5" name="request-id"/>
# <meta content="#fff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/static/shared-web/favicon-4e1897dfd0901e8a3bf7e604d3a90636.ico" rel="icon"/>
# <link href="/static/shared-web/iphone-7c4d7dcb05fece466d8901945e36bbaa.png" rel="apple-touch-icon"/>
# <link href="/static/shared-web/ipad-96988dd1c0902fd20b34ce260d03729b.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/static/shared-web/iphoneRetina-c772d091f011ef7ce26f631360de4907.png" rel="apple-touch-icon" sizes="120x120"/>
# ...

# %%
print(div_job)
# Out:
# None

# %%
# Test code for selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

# Do not seperate the code block
driver = webdriver.Chrome()

url = "https://ph.indeed.com/"

# Access the set url
driver.get(url)

# Wait for the 15 seconds before finding the element
driver.implicitly_wait(15)

# get the element
element = driver.find_element(By.ID, "text-input-what")

element.send_keys("test")

# %%
# Import necessary packages
from bs4 import BeautifulSoup
import requests

# url = "https://www.glassdoor.com/blog/tag/job-search/"
url = "https://ph.indeed.com/"

page = requests.get(url)
soup = BeautifulSoup(page.text, "html")  # Pull the information from the URL

div_job = soup.find(
    "div", class_="jobsearch-JobComponent-description css-10ybyod eu4oa1w0"
)
print(div_job)

# %%
# Test code for selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests


# Do not seperate the code block
driver = webdriver.Chrome()

url = "https://www.glassdoor.com/Job/index.htm"

page = requests.get(url)
soup = BeautifulSoup(page.text, "html")  # Pull the information from the URL

# Access the set url
driver.get(url)

# Wait for the 15 seconds before finding the element
driver.implicitly_wait(15)

# get the element
# job_input = driver.find_element(By.ID, "text-input-what")

# job_input.send_keys("data entry")


# driver.implicitly_wait(15)

# Locate the search job button
job_search = driver.find_element(
    By.ID,
    "searchBar-jobTitle",
)

driver.implicitly_wait(15)
job_search.send_keys("data analyst")
driver.implicitly_wait(15)
job_search.submit()


# div_job = soup.find("span", class_="css-htco8s es2vvo70")

# print(div_job)

# %%
<button class="yosegi-InlineWhatWhere-primaryButton" type="submit">Find jobs</button>

driver.find_element(By.CLASS_NAME, "content")
